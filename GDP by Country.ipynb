# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://www.worldometers.info/gdp/gdp-by-country/'
page = requests.get(url)

# %%
page
# Out:
# <Response [200]>

# %%
doc = lh.fromstring(page.content)
elems= doc.xpath('//tr')

# %%
elems
# Out:
# [<Element tr at 0x2a11b80ef90>,
#  <Element tr at 0x2a11b829040>,
#  <Element tr at 0x2a11b829090>,
#  <Element tr at 0x2a11b8290e0>,
#  <Element tr at 0x2a11b829130>,
#  <Element tr at 0x2a11b829180>,
#  <Element tr at 0x2a11b8291d0>,
#  <Element tr at 0x2a11b829220>,
#  <Element tr at 0x2a11b829270>,
#  <Element tr at 0x2a11b8292c0>,
#  <Element tr at 0x2a11b829310>,
#  <Element tr at 0x2a11b829360>,
#  <Element tr at 0x2a11b8293b0>,
#  <Element tr at 0x2a11b829400>,
#  <Element tr at 0x2a11b829450>,
#  <Element tr at 0x2a11b8294a0>,
#  <Element tr at 0x2a11b8294f0>,
#  <Element tr at 0x2a11b829540>,
#  <Element tr at 0x2a11b829590>,
#  <Element tr at 0x2a11b8295e0>,
#  <Element tr at 0x2a11b829630>,
#  <Element tr at 0x2a11b829680>,
#  <Element tr at 0x2a11b8296d0>,
#  <Element tr at 0x2a11b829720>,
#  <Element tr at 0x2a11b829770>,
#  <Element tr at 0x2a11b8297c0>,
#  <Element tr at 0x2a11b829810>,
#  <Element tr at 0x2a11b829860>,
#  <Element tr at 0x2a11b8298b0>,
# ...

# %%
len (elems)
# Out:
# 191

# %%
cols=[]

for e in elems[0]:
    name=e.text_content()
    print (name)
    cols.append((name,[]))
# Out:
# #
# Country
# GDP (nominal, 2017)
# GDP (abbrev.)
# GDP  growth
# Population (2017)
# GDP  per capita
# Share of World GDP

# %%
cols
# Out:
# [('#', []),
#  ('Country', []),
#  ('GDP (nominal, 2017) ', []),
#  ('GDP (abbrev.)', []),
#  ('GDP  growth', []),
#  ('Population (2017) ', []),
#  ('GDP  per capita ', []),
#  ('Share of World GDP ', [])]

# %%
len (cols)
# Out:
# 8

# %%
for j in range(1,len(elems)):
    
    E=elems[j]
    i=0
    
    for h in E.iterchildren():
        data=h.text_content() 
        print (data)
        if i>0:
            try:
                data=int(data)
            except:
                pass
        cols[i][1].append(data)
        i+=1
# Out:
# 1
# United States
# $19,485,394,000,000
# $19.485 trillion
# 2.27%
# 325,084,756
# $59,939
# 24.08%
# 2
# China
# $12,237,700,479,375
# $12.238 trillion
# 6.90%
# 1,421,021,791
# $8,612
# 15.12%
# 3
# Japan
# $4,872,415,104,315
# $4.872 trillion
# 1.71%
# 127,502,725
# $38,214
# 6.02%
# 4
# Germany
# $3,693,204,332,230
# $3.693 trillion
# 2.22%
# 82,658,409
# $44,680
# 4.56%
# 5
# India
# $2,650,725,335,364
# $2.651 trillion
# 6.68%
# 1,338,676,785
# $1,980
# 3.28%
# 6
# United Kingdom
# $2,637,866,340,434
# $2.638 trillion
# 1.79%
# 66,727,461
# $39,532
# 3.26%
# 7
# France
# $2,582,501,307,216
# $2.583 trillion
# 1.82%
# 64,842,509
# $39,827
# 3.19%
# 8
# Brazil
# $2,053,594,877,013
# $2.054 trillion
# 0.98%
# 207,833,823
# $9,881
# 2.54%
# 9
# Italy
# $1,943,835,376,342
# $1.944 trillion
# 1.50%
# 60,673,701
# $32,038
# 2.40%
# 10
# Canada
# $1,647,120,175,449
# $1.647 trillion
# 3.05%
# 36,732,095
# $44,841
# 2.04%
# 11
# Russia
# $1,578,417,211,937
# $1.578 trillion
# 1.55%
# ...

# %%
Dict={title:column for (title,column) in cols}
df=pd.DataFrame(Dict)

# %%
df
# Out:
#        #           Country GDP (nominal, 2017)      GDP (abbrev.) GDP  growth  \
# 0      1     United States  $19,485,394,000,000  $19.485 trillion       2.27%
# 1      2             China  $12,237,700,479,375  $12.238 trillion       6.90%
# 2      3             Japan   $4,872,415,104,315   $4.872 trillion       1.71%
# 3      4           Germany   $3,693,204,332,230   $3.693 trillion       2.22%
# 4      5             India   $2,650,725,335,364   $2.651 trillion       6.68%
# ..   ...               ...                  ...               ...         ...
# 185  186        Micronesia         $336,427,500      $336 million       3.20%
# 186  187             Palau         $289,823,500      $290 million      -3.57%
# 187  188  Marshall Islands         $204,173,430      $204 million       3.60%
# 188  189          Kiribati         $185,572,502      $186 million       0.33%
# 189  190            Tuvalu          $39,731,317       $40 million       3.24%
#
# ...

# %%
df.to_csv('Sample_data_Haibo Wang.csv')
